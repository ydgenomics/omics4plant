# %% [markdown]
# # 2026-02-11
# 苜蓿下载的gtf和基因组跑checkGTF，报错ERROR: Multiple gene IDs appear at the same position on the same strand of the same chromosome, on the lines: [102157 102160 137141 137144 240466 240471 291476 291479 297604 297607 451942 451945 828153 828156 1014402 1014405 ]. 主要是同一区段（chr-start-stop-strand），注释为同一类别，但是有不同基因名gene_id，不同gene_id的存在是因为source不同即注释软件不同导致，比较方便的方法就是删除只保留唯一的，使用手动最好。之前使用自动，删减错误导致exon缺少，导致后续跑makeRef一直stop阶段，对gtf进行统计才发现exon缺失，所以对gtf结构和STAR逻辑掌握很重要，学习了一些shell查看命名，`awk`, `sed`等。
