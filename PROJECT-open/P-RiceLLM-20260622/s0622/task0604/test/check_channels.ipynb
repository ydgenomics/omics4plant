# %%
train_list = ['data/indices/test_CSQ_Z_P10_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P11_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P12_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P13_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P14_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P1_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P2_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P3_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P4_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P5_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P6_multitrack/sequence_split_train.csv', 
'data/indices/test_CSQ_Z_P7_multitrack/sequence_split_train.csv']
len(train_list)
# Out:
# 12
