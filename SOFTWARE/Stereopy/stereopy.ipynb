# %% [markdown]
# cellcute，解决表达扩散的问题

# %% [markdown]
# 输入和输出 https://stereopy.readthedocs.io/en/latest/Tutorials/IO.html

# %% [markdown]
# gef和gem转换

# %% [markdown]
# GEM and GEF
# gem包含5列，geneID,X,Y,MIDCount,ExonCount
# bin_size=[], bin_type=['bins', 'cell_bins']
# spot_size=220nm, 两个spot中点（center-to-centor）的距离为500nm

# %% [markdown]
# 可视化某基因

# %%
target_gene='Chr2012264'
data.plt.spatial_scatter_by_gene(gene_name=target_gene)

# %% [markdown]
# 得到局部对象的gef/Getting a sub-object https://stereopy.readthedocs.io/en/latest/Tutorials/High_Resolution_Export.html#Getting-a-sub-object

# %%
# 单对象
selected_exp_data = ins.selected_exp_data
selected_exp_data

# %%
# 多对象
selected_exp_data_all = ins.get_selected_areas(drop=False)
selected_exp_data_all

# %%
# 导出对象选中的对象/Exporting as a GEF/GEM file
ins.export_high_res_area(
    data_path,
    './SS200000135TL_D1.tissue.high_res.gef',
    # drop=True
)

# Exporting a sub-image
ins.export_roi_image(
    origin_file_path='../data/SS200000135TL_D1_regist.tif',
    output_path='./SS200000135TL_D1_regist_selected.tif',
    # drop=True
)
